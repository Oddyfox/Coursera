# %% [markdown]
# # Visualization Lab

# %% [markdown]
# The goal of this lab is to gain familiarity with a few of the many plotting options in the Matplotlib library.  We will begin by exploring how different colorbars affect the perception of your data and then make a few different plots to practice line plots, histograms, and box plots.  The goal of this lab is to make visualization you would be eager to share with others, so remember to include meaningful axes labels and titles.

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable

# %% [markdown]
# Let's begin by generating some two dimensional data.  Run the code below to make a donut, but feel free to tweak the code to make other, more interesting data.

# %%
nx, ny = (200, 200)
x = np.linspace(-1, 1, nx)
y = np.linspace(-1, 1, ny)

X, Y = np.meshgrid(x, y)
R = np.sqrt(X**2 + Y**2)

z = np.sin(R*2.)**2

# %% [markdown]
# To plot this data, use the `pcolormesh` function in Matplotlib.  We will add a second plot to this figure next, so save some hassle and set it up as a subplot with `subplots`.

# %%
fig, ax = plt.subplots(1,1, figsize=(6,5))   # call to make figure and axes
im =  plt.pcolormesh( X, Y, z )
# Out:
# /opt/conda/envs/sagemaker-soln/lib/python3.7/site-packages/ipykernel_launcher.py:2: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.

# %% [markdown]
# The plot shows the data, but it isn't very informative.  To make the plot look nice we also want to exercise some control over the axes to declutter them by setting the tick marks to be in intervals of 0.5. Also, add "x Coordinate", and "y Coordinate" axes labels.  Remake the figure with this change.

# %%
fig, ax = plt.subplots(1,1, figsize=(6,5)) # call to make figure and axes
im = plt.pcolormesh( X, Y, z )# pcolormesh

# format ticks
plt.xticks( np.arange( -1, 1.5, 0.5 ) )
plt.yticks( np.arange( -1, 1.5, 0.5 ) )

# add axes labels
plt.xlabel( 'x Coordinate' )
plt.ylabel( 'y Coordinate' )
# Out:
# /opt/conda/envs/sagemaker-soln/lib/python3.7/site-packages/ipykernel_launcher.py:2: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
# Text(0, 0.5, 'y Coordinate')

# %% [markdown]
# Now we can see the data and know the axes, but we still don't know what the values are.  It is important to show the color bar so others have a reference for the scale, which can be added with colorbar.  Make this final change and remake the figure.

# %%
fig, ax = plt.subplots(1,1, figsize=(6,5)) # call to make figure and axes
im = plt.pcolormesh( X, Y, z )# pcolormesh

# format ticks
plt.xticks( np.arange( -1, 1.5, 0.5 ) )
plt.yticks( np.arange( -1, 1.5, 0.5 ) )

# add axes labels
plt.xlabel( 'x Coordinate' )
plt.ylabel( 'y Coordinate' )

# add colorbar
plt.colorbar( )
# Out:
# /opt/conda/envs/sagemaker-soln/lib/python3.7/site-packages/ipykernel_launcher.py:2: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.

# %% [markdown]
# The 2D plot gives a good sense of the global function, but let's dive into it more by taking a slice through a row or column and show it in a second subplot.  Rather than assembling the entire plot in one go, let's build it step-by-step.  First, make a slice of the data, for instance horizontally through the 100th row (index 99).

# %%
z.shape
# Out:
# (200, 200)

# %%
cut = z[ 99 ]

# %%
cut.shape
# Out:
# (200,)

# %% [markdown]
# To check that we've done things correctly, plot the graph of `x` vs the values of `cut`.

# %%
fig, ax = plt.subplots(1,1, figsize=(6,5)) # call to make figure and axes
im =  plt.plot( x, cut ) # plot

# %% [markdown]
# Let's again remake the plot with tidier ticks and label the axes.

# %%
fig, ax = plt.subplots(1,1, figsize=(6,5)) # call to make figure and axes
im =  plt.plot( x, cut ) # plot

# format ticks
plt.xticks( np.arange( -1, 1.5, 0.5 ) )
plt.yticks( np.arange( 0, 1.5, 0.5 ) )

# add axes labels
plt.xlabel( 'x Coordinate' )
plt.ylabel( 'y Coordinate' )
# Out:
# Text(0, 0.5, 'y Coordinate')

# %% [markdown]
# Between the 2D plot and the line plot, we have two nice looking plots.  Let's show each of them as subplots with the 2D plot as the first and the line plot as the second.  Be sure to include the formatting changes we have made.

# %%
fig, (ax1, ax2) = plt.subplots(2,1, figsize=(15,15)) # make figure and two sets of subplot axes
im1 = ax1.pcolormesh( X, Y, z, cmap = 'inferno' )# pcolormesh

# set colorbar for ax1
#ax1.colorbar( ax = ax1 )
fig.colorbar(im1, orientation='vertical', ax = ax1)

# format ax1 axes ticks
ax1.set_xticks( np.arange( -1, 1.5, 0.5 ) )
ax1.set_yticks( np.arange( -1, 1.5, 0.5 ) )

# add ax1 axes labels
ax1.set_xlabel( 'x Coordinate' )
ax1.set_ylabel( 'y Coordinate' )

im2 = ax2.plot( x, cut ) # plot slice

# format ax2 x-axis ticks
plt.xticks( np.arange( -1, 1.5, 0.5 ) )
plt.yticks( np.arange( 0, 1.5, 0.5 ) )

# add ax2 axes labels
ax2.set_xlabel( 'x Coordinate' )
ax2.set_ylabel( 'y Coordinate' )

plt.tight_layout( 3 )
# Out:
# /opt/conda/envs/sagemaker-soln/lib/python3.7/site-packages/ipykernel_launcher.py:2: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#
# /opt/conda/envs/sagemaker-soln/lib/python3.7/site-packages/ipykernel_launcher.py:26: MatplotlibDeprecationWarning: Passing the pad parameter of tight_layout() positionally is deprecated since Matplotlib 3.3; the parameter will become keyword-only two minor releases later.

# %% [markdown]
# Play around a bit with the color bars on the 2D plot to see which you like best and to understand how it affects perception.  The ones we saw in lecture (`jet`, `gray`, and `inferno`) are a good starting point, but feel free to try the others provided by Matplotlib.

# %% [markdown]
# Contour plots are also useful for visualizing 2D data.  Let's make one of our data with either `contour` for a normal contour plot or `contourf` for a filled contour plot.  `colorbar` will take on the role of showing the contour levels, which we can adjust with the `levels` parameter.  We can either explicitly pass levels in an array or simply tell it the number of levels we want to plot.

# %%
fig, ax = plt.subplots(1,1, figsize=(10,10))# call to make figure and axes
im =  plt.contourf( X, Y, z, levels = 20, cmap = 'inferno' )# contour

# format ticks
plt.xticks( np.arange( -1, 1.5, 0.5 ) )
plt.yticks( np.arange( -1, 1.5, 0.5 ) )

# add axes labels
plt.xlabel( 'x Coordinate' )
plt.ylabel( 'y Coordinate' )

# add colorbar
plt.colorbar( )

# %% [markdown]
# # Examine Seattle Housing dataset
#
# In this section we will look at the Seattle area housing dataset.

# %%
import pandas as pd

# %%
df = pd.read_csv("data/kc_house_data.csv")

# %% [markdown]
# Plot the price column use `plot`

# %%
df.head( )
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503
#
# [5 rows x 21 columns]

# %%
df.plot( x = 'price', y = 'sqft_living', kind = 'scatter' )
# Out:
# <AxesSubplot:xlabel='price', ylabel='sqft_living'>

# %% [markdown]
# Build a histogram of all the columns in the dataset.  Use `hist`
#
#
# You may want to experiment with passing custom figsize and sharey parameters to get more legible output

# %%
df.hist( figsize = ( 15,15 ) )
# Out:
# array([[<AxesSubplot:title={'center':'id'}>,
#         <AxesSubplot:title={'center':'price'}>,
#         <AxesSubplot:title={'center':'bedrooms'}>,
#         <AxesSubplot:title={'center':'bathrooms'}>],
#        [<AxesSubplot:title={'center':'sqft_living'}>,
#         <AxesSubplot:title={'center':'sqft_lot'}>,
#         <AxesSubplot:title={'center':'floors'}>,
#         <AxesSubplot:title={'center':'waterfront'}>],
#        [<AxesSubplot:title={'center':'view'}>,
#         <AxesSubplot:title={'center':'condition'}>,
#         <AxesSubplot:title={'center':'grade'}>,
#         <AxesSubplot:title={'center':'sqft_above'}>],
#        [<AxesSubplot:title={'center':'sqft_basement'}>,
#         <AxesSubplot:title={'center':'yr_built'}>,
#         <AxesSubplot:title={'center':'yr_renovated'}>,
#         <AxesSubplot:title={'center':'zipcode'}>],
#        [<AxesSubplot:title={'center':'lat'}>,
#         <AxesSubplot:title={'center':'long'}>,
#         <AxesSubplot:title={'center':'sqft_living15'}>,
#         <AxesSubplot:title={'center':'sqft_lot15'}>]], dtype=object)

# %% [markdown]
# Make a histogram of just the bedroom column

# %%
df[ 'bedrooms' ].hist( bins = 30 )
# Out:
# <AxesSubplot:>

# %% [markdown]
# We'll need it for the assingment below

# %%
from math import log

# %% [markdown]
# Load the housing dataset

# %%
houses = pd.read_csv('data/kc_house_data.csv')

# %%
houses.hist( figsize = ( 15,15 ) )
# Out:
# array([[<AxesSubplot:title={'center':'id'}>,
#         <AxesSubplot:title={'center':'price'}>,
#         <AxesSubplot:title={'center':'bedrooms'}>,
#         <AxesSubplot:title={'center':'bathrooms'}>],
#        [<AxesSubplot:title={'center':'sqft_living'}>,
#         <AxesSubplot:title={'center':'sqft_lot'}>,
#         <AxesSubplot:title={'center':'floors'}>,
#         <AxesSubplot:title={'center':'waterfront'}>],
#        [<AxesSubplot:title={'center':'view'}>,
#         <AxesSubplot:title={'center':'condition'}>,
#         <AxesSubplot:title={'center':'grade'}>,
#         <AxesSubplot:title={'center':'sqft_above'}>],
#        [<AxesSubplot:title={'center':'sqft_basement'}>,
#         <AxesSubplot:title={'center':'yr_built'}>,
#         <AxesSubplot:title={'center':'yr_renovated'}>,
#         <AxesSubplot:title={'center':'zipcode'}>],
#        [<AxesSubplot:title={'center':'lat'}>,
#         <AxesSubplot:title={'center':'long'}>,
#         <AxesSubplot:title={'center':'sqft_living15'}>,
#         <AxesSubplot:title={'center':'sqft_lot15'}>]], dtype=object)

# %% [markdown]
# Find the feature with the most flat distribution,  use the histograms of the enitre dataset we build couple of cells above.  Modify the visualization below to shot it on the map either as color or as alpha. If things don't look to good try applying a log or square root function to that attribute.  Use pow to apply a square root.
#
# Add a third map to see to the visualization to see if there are two different variables that affect the house price.

# %%
plt.rcParams['figure.figsize'] = [15, 5]
fig, ax = plt.subplots(1, 3)


p1 = ax[0].scatter( x=houses.long, y=-houses.lat,  s=4,  c=np.log(houses.price)/log(10),  alpha=0.4,  cmap="jet"),
p2 = ax[1].scatter( x=houses.long, y=-houses.lat,  s=4,  c=houses.bedrooms.pow(0.5),  alpha=0.4,  cmap="jet"),
p3 = ax[2].scatter( x=houses.long, y=-houses.lat,  s=4,  c=houses.yr_built.pow(0.5),  alpha=0.4,  cmap="jet"),

fig.colorbar(p3[0], ax=ax, orientation='vertical')
